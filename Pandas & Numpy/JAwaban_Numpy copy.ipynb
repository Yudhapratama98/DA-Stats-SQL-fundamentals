# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import regex as re

# %%
display(np.__version__)
display(pd.__version__)
print(np.__version__)
print(pd.__version__)
# Out:
# '1.21.6'
# '1.3.5'
# 1.21.6
# 1.3.5

# %% [markdown]
# # __Dataset: Salaries.csv__

# %% [markdown]
# ## **No.1**

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html

# %%
# load dataset
df = pd.read_csv('/content/drive/MyDrive/JCDS Practice Session VL-04, 06/Modul 2/Week 3/Thursday, June 02, 2022/Salaries.csv')
display(df.head()) # secara default 5 data teratas
display(df.tail()) # #secara default 5 data teratas
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %% [markdown]
# ## **No.2**

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sum.html

# %%
# df.isna()
df.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False     True         True      True
# 148651  False         False     False     True         True      True
# 148652  False         False     False     True         True      True
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
# check missing value
# df.isna().sum()
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.Series.str.len.html

# %%
len(df)
# Out:
# 148654

# %%
609/148654*100
# Out:
# 0.40967616074912216

# %%
# missing value in percentage
df.isna().sum()/len(df)*100
# Out:
# Id                    0.000000
# EmployeeName          0.000000
# JobTitle              0.000000
# BasePay               0.409676
# OvertimePay           0.002691
# OtherPay              0.002691
# Benefits             24.326961
# TotalPay              0.000000
# TotalPayBenefits      0.000000
# Year                  0.000000
# Notes               100.000000
# Agency                0.000000
# Status              100.000000
# dtype: float64

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html

# %%
# # drop kolom yang banyak missing valuenya
# df.drop(columns=['Notes','Status'], inplace=True)

# %%
# drop kolom yang banyak missing valuenya (> 50%)
df.drop(df.columns[df.isna().sum()/len(df)>0.5],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          148654 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Agency            148654 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 12.5+ MB

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html

# %%
# isi missing value di kolom Benefits dengan nilai 0
df['Benefits'].fillna(value=0, inplace=True)

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

# %%
# hapus baris yang memiliki missing value
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year         Agency
# 0  2011  San Francisco
# ...

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html

# %%
# sisa kolom dan baris setelah hapus missing value
df.shape
# Out:
# (148045, 11)

# %% [markdown]
# ## **No.3**

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

# %%
# descriptive statistic
df.describe(include='all')
# Out:
#                    Id EmployeeName          JobTitle        BasePay  \
# count   148045.000000       148045            148045  148045.000000
# unique            NaN       110313              2154            NaN
# top               NaN    Kevin Lee  Transit Operator            NaN
# freq              NaN           13              6975            NaN
# mean     74192.680030          NaN               NaN   66325.448841
# std      42948.484911          NaN               NaN   42764.635495
# min          1.000000          NaN               NaN    -166.010000
# 25%      37012.000000          NaN               NaN   33588.200000
# 50%      74023.000000          NaN               NaN   65007.450000
# 75%     111639.000000          NaN               NaN   94691.050000
# max     148654.000000          NaN               NaN  319275.010000
#
#           OvertimePay       OtherPay       Benefits       TotalPay  \
# count   148045.000000  148045.000000  148045.000000  148045.000000
# ...

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148045.000000  148045.000000  148045.000000  148045.000000
# mean    74192.680030   66325.448841    5086.740800    3645.661408
# std     42948.484911   42764.635495   11473.181557    8019.498636
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37012.000000   33588.200000       0.000000       0.000000
# 50%     74023.000000   65007.450000       0.000000     817.170000
# 75%    111639.000000   94691.050000    4695.710000    4242.900000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year
# count  148045.000000  148045.000000     148045.000000  148045.000000
# mean    18980.334019   75057.851048      94038.185067    2012.520653
# std     17176.391332   50409.761170      62683.477905       1.119390
# min       -13.800000    -618.130000       -618.130000    2011.000000
# ...

# %%
# df.describe(include='object')
df.describe(include=object)
# Out:
#        EmployeeName          JobTitle         Agency
# count        148045            148045         148045
# unique       110313              2154              1
# top       Kevin Lee  Transit Operator  San Francisco
# freq             13              6975         148045

# %% [markdown]
# ## **No.4**

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html

# %%
df['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148645         0.00
# 148647         0.00
# 148648         0.00
# 148649         0.00
# 148653         0.00
# Name: BasePay, Length: 148045, dtype: float64

# %%
df[['BasePay']]
# Out:
#           BasePay
# 0       167411.18
# 1       155966.02
# 2       212739.13
# 3        77916.00
# 4       134401.60
# ...           ...
# 148645       0.00
# 148647       0.00
# 148648       0.00
# 148649       0.00
# 148653       0.00
#
# [148045 rows x 1 columns]

# %%
# rata-rata gaji pokok
df['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
df[['BasePay']].mean()
# Out:
# BasePay    66325.448841
# dtype: float64

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html

# %%
# Pekerjaan terbanyak
df['JobTitle'].mode()
# Out:
# 0    Transit Operator
# dtype: object

# %%
df[['JobTitle']].mode()
# Out:
#            JobTitle
# 0  Transit Operator

# %%
df_mode = df.groupby('JobTitle')
df_mode.count()[df_mode.count()['Id'] == df_mode.count()['Id'].max()]
# Out:
#                     Id  EmployeeName  BasePay  OvertimePay  OtherPay  \
# JobTitle
# Transit Operator  6975          6975     6975         6975      6975
#
#                   Benefits  TotalPay  TotalPayBenefits  Year  Agency
# JobTitle
# Transit Operator      6975      6975              6975  6975    6975

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html

# %%
df['JobTitle'].value_counts().head(1)
# Out:
# Transit Operator    6975
# Name: JobTitle, dtype: int64

# %%
df[['JobTitle']].value_counts().head(1)
# Out:
# JobTitle
# Transit Operator    6975
# dtype: int64

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.max.html

# %%
# uang lembur terbesar
df['OvertimePay'].max()
# Out:
# 245131.88

# %%
df[['OvertimePay']].max()
# Out:
# OvertimePay    245131.88
# dtype: float64

# %% [markdown]
# ## **No.5**

# %% [markdown]
# 1. https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html
# 1. https://pandas.pydata.org/pandas-docs/stable/user_guide/cookbook.html#cookbook-selection
# 1. https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#indexing-view-versus-copy
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html

# %% [markdown]
# ### Karyawan bernama Rosemary Lee dan pekerjaannya

# %%
df['EmployeeName']=='Rosemary Lee'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: EmployeeName, Length: 148045, dtype: bool

# %%
df.loc[df['EmployeeName']=='Rosemary Lee']
# Out:
#           Id  EmployeeName       JobTitle    BasePay  OvertimePay  OtherPay  \
# 36497  36498  Rosemary Lee  Nurse Manager  177158.02        453.8  18415.81
#
#        Benefits   TotalPay  TotalPayBenefits  Year         Agency
# 36497  59631.33  196027.63         255658.96  2012  San Francisco

# %%
df.loc[df['EmployeeName']=='Rosemary Lee', ['EmployeeName','JobTitle']]
# Out:
#        EmployeeName       JobTitle
# 36497  Rosemary Lee  Nurse Manager

# %%
df[['EmployeeName','JobTitle']].tail()
# Out:
#             EmployeeName                     JobTitle
# 148645  Carolyn A Wilson    Human Services Technician
# 148647    Joann Anderson  Communications Dispatcher 2
# 148648       Leon Walker                    Custodian
# 148649     Roy I Tillery                    Custodian
# 148653         Joe Lopez   Counselor, Log Cabin Ranch

# %%
df.loc[df['EmployeeName']=='Rosemary Lee'] [['EmployeeName','JobTitle']]
# Out:
#        EmployeeName       JobTitle
# 36497  Rosemary Lee  Nurse Manager

# %%
df[df['EmployeeName']=='Rosemary Lee']
# Out:
#           Id  EmployeeName       JobTitle    BasePay  OvertimePay  OtherPay  \
# 36497  36498  Rosemary Lee  Nurse Manager  177158.02        453.8  18415.81
#
#        Benefits   TotalPay  TotalPayBenefits  Year         Agency
# 36497  59631.33  196027.63         255658.96  2012  San Francisco

# %%
df[df['EmployeeName']=='Rosemary Lee'], ['EmployeeName','JobTitle']
# Out:
# (          Id  EmployeeName       JobTitle    BasePay  OvertimePay  OtherPay  \
#  36497  36498  Rosemary Lee  Nurse Manager  177158.02        453.8  18415.81
#
#         Benefits   TotalPay  TotalPayBenefits  Year         Agency
#  36497  59631.33  196027.63         255658.96  2012  San Francisco  ,
#  ['EmployeeName', 'JobTitle'])

# %%
df[df['EmployeeName']=='Rosemary Lee'] [['EmployeeName','JobTitle']]
# Out:
#        EmployeeName       JobTitle
# 36497  Rosemary Lee  Nurse Manager

# %%
df[['EmployeeName','JobTitle']].head()
# Out:
#         EmployeeName                                        JobTitle
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)

# %%
df[['EmployeeName','JobTitle']],[df['EmployeeName']=='Rosemary Lee']
# Out:
# (             EmployeeName                                        JobTitle
#  0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#  1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#  2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#  3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
#  4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#  ...                   ...                                             ...
#  148645   Carolyn A Wilson                       Human Services Technician
#  148647     Joann Anderson                     Communications Dispatcher 2
#  148648        Leon Walker                                       Custodian
#  148649      Roy I Tillery                                       Custodian
#  148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#  [148045 rows x 2 columns], [0         False
#   1         False
# ...

# %%
df[['EmployeeName','JobTitle']] [df['EmployeeName']=='Rosemary Lee']
# Out:
#        EmployeeName       JobTitle
# 36497  Rosemary Lee  Nurse Manager

# %%
display(df[['EmployeeName','JobTitle']] [df['EmployeeName']=='Rosemary Lee'])

print(df[['EmployeeName','JobTitle']] [df['EmployeeName']=='Rosemary Lee'])
# Out:
#        EmployeeName       JobTitle
# 36497  Rosemary Lee  Nurse Manager
#        EmployeeName       JobTitle
# 36497  Rosemary Lee  Nurse Manager

# %% [markdown]
# ### Nama karyawan dengan TotalPayBenefits paling besar

# %%
df['TotalPayBenefits']
# Out:
# 0         567595.43
# 1         538909.28
# 2         335279.91
# 3         332343.61
# 4         326373.19
#             ...
# 148645         0.00
# 148647         0.00
# 148648         0.00
# 148649         0.00
# 148653      -618.13
# Name: TotalPayBenefits, Length: 148045, dtype: float64

# %%
df['TotalPayBenefits'] == df['TotalPayBenefits'].max()
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: TotalPayBenefits, Length: 148045, dtype: bool

# %%
df[df['TotalPayBenefits'] == df['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       0.0  567595.43         567595.43
#
#    Year         Agency
# 0  2011  San Francisco

# %%
df[df['TotalPayBenefits'] == df['TotalPayBenefits'].max()][['EmployeeName','TotalPayBenefits']]
# Out:
#      EmployeeName  TotalPayBenefits
# 0  NATHANIEL FORD         567595.43

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.idxmax.html
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html

# %%
df['TotalPayBenefits']
# Out:
# 0         567595.43
# 1         538909.28
# 2         335279.91
# 3         332343.61
# 4         326373.19
#             ...
# 148645         0.00
# 148647         0.00
# 148648         0.00
# 148649         0.00
# 148653      -618.13
# Name: TotalPayBenefits, Length: 148045, dtype: float64

# %%
df['TotalPayBenefits'].idxmax()
# Out:
# 0

# %%
df.iloc[df['TotalPayBenefits'].idxmax()]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       0.0
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Agency                                               San Francisco
# Name: 0, dtype: object

# %%
df.iloc[[df['TotalPayBenefits'].idxmax()]]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       0.0  567595.43         567595.43
#
#    Year         Agency
# 0  2011  San Francisco

# %%
df.iloc[[df['TotalPayBenefits'].idxmax()]][['EmployeeName','TotalPayBenefits']]
# Out:
#      EmployeeName  TotalPayBenefits
# 0  NATHANIEL FORD         567595.43

# %%
print(df.iloc[[df['TotalPayBenefits'].idxmax()]][['EmployeeName','TotalPayBenefits']])
# Out:
#      EmployeeName  TotalPayBenefits
# 0  NATHANIEL FORD         567595.43

# %%
df['TotalPayBenefits'].idxmax()
# Out:
# 0

# %%
df.iloc[[0]] [['EmployeeName','TotalPayBenefits']]
# Out:
#      EmployeeName  TotalPayBenefits
# 0  NATHANIEL FORD         567595.43

# %%
max_pay = df['TotalPayBenefits'].max()

df[df['TotalPayBenefits'] == max_pay] [['EmployeeName','TotalPayBenefits']]
# Out:
#      EmployeeName  TotalPayBenefits
# 0  NATHANIEL FORD         567595.43

# %% [markdown]
# ## **No.6**

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html

# %% [markdown]
# ### Rata-rata BasePay pertahun

# %%
df[['BasePay']].mean()
# Out:
# BasePay    66325.448841
# dtype: float64

# %%
df.groupby(by='Year')

# %%
df.groupby(by='Year')[['BasePay']].mean()
# Out:
#            BasePay
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %%
df.groupby(by='Year').mean()
# Out:
#                  Id       BasePay  OvertimePay     OtherPay      Benefits  \
# Year
# 2011   18080.000000  63595.956517  4531.065429  3617.081926      0.000000
# 2012   54542.500000  65436.406857  5023.417824  3653.437583  26439.966967
# 2013   91481.627632  69630.030216  5367.913512  3810.341313  24131.696305
# 2014  129591.000184  66564.421924  5401.993737  3505.421251  24789.601756
#
#           TotalPay  TotalPayBenefits
# Year
# 2011  71744.103871      71744.103871
# 2012  74113.262265     100553.229232
# 2013  78808.285041     102939.981346
# 2014  75471.836912     100261.438668

# %%
df['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148645         0.00
# 148647         0.00
# 148648         0.00
# 148649         0.00
# 148653         0.00
# Name: BasePay, Length: 148045, dtype: float64

# %%
df[['BasePay']]
# Out:
#           BasePay
# 0       167411.18
# 1       155966.02
# 2       212739.13
# 3        77916.00
# 4       134401.60
# ...           ...
# 148645       0.00
# 148647       0.00
# 148648       0.00
# 148649       0.00
# 148653       0.00
#
# [148045 rows x 1 columns]

# %%
df.groupby(by='Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
df.groupby(by='Year').mean()[['BasePay']]
# Out:
#            BasePay
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %%
df_year = df.groupby('Year')
df_year['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ### Top 5 JobTitle terbanyak

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html

# %%
df_JobTitle = df.groupby('JobTitle',as_index=False).count()
df_JobTitle
# Out:
#                                             JobTitle   Id  EmployeeName  \
# 0                                      ACCOUNT CLERK   83            83
# 1                                         ACCOUNTANT    5             5
# 2                                  ACCOUNTANT INTERN   48            48
# 3                        ACPO,JuvP, Juv Prob (SFERS)    1             1
# 4                                      ACUPUNCTURIST    1             1
# ...                                              ...  ...           ...
# 2149                           X-RAY LABORATORY AIDE   26            26
# 2150                           X-Ray Laboratory Aide  100           100
# 2151  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    1             1
# 2152                              Youth Comm Advisor    4             4
# 2153                                     ZOO CURATOR    1             1
#
#       BasePay  OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
df_JobTitle = df.groupby('JobTitle',as_index=False).count().sort_values('Id',ascending=False)
df_JobTitle
# Out:
#                                JobTitle    Id  EmployeeName  BasePay  \
# 2051                   Transit Operator  6975          6975     6975
# 1897                      Special Nurse  4382          4382     4382
# 1572                   Registered Nurse  3725          3725     3725
# 1539       Public Svc Aide-Public Works  2514          2514     2514
# 1478                   Police Officer 3  2411          2411     2411
# ...                                 ...   ...           ...      ...
# 1161                         METALSMITH     1             1        1
# 1160                   METAL FABRICATOR     1             1        1
# 1157      MENTAL HEALTH HEARING OFFICER     1             1        1
# 1143  MEDIA/SECURITY SYSTEMS SUPERVISOR     1             1        1
# 2153                        ZOO CURATOR     1             1        1
#
#       OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# ...

# %%
df_JobTitle = df.groupby('JobTitle',as_index=False).count().sort_values('Id',ascending=False).head()
df_JobTitle[['JobTitle']]
# Out:
#                           JobTitle
# 2051              Transit Operator
# 1897                 Special Nurse
# 1572              Registered Nurse
# 1539  Public Svc Aide-Public Works
# 1478              Police Officer 3

# %%
df['JobTitle'].value_counts().head()
# Out:
# Transit Operator                6975
# Special Nurse                   4382
# Registered Nurse                3725
# Public Svc Aide-Public Works    2514
# Police Officer 3                2411
# Name: JobTitle, dtype: int64

# %%
df[['JobTitle']].value_counts().head()
# Out:
# JobTitle
# Transit Operator                6975
# Special Nurse                   4382
# Registered Nurse                3725
# Public Svc Aide-Public Works    2514
# Police Officer 3                2411
# dtype: int64

# %%
df.groupby('JobTitle')

# %% [markdown]
# #### JobTitle menjadi index

# %%
df.groupby('JobTitle').count()
# Out:
#                                                  Id  EmployeeName  ...  Year  Agency
# JobTitle                                                           ...
# ACCOUNT CLERK                                    83            83  ...    83      83
# ACCOUNTANT                                        5             5  ...     5       5
# ACCOUNTANT INTERN                                48            48  ...    48      48
# ACPO,JuvP, Juv Prob (SFERS)                       1             1  ...     1       1
# ACUPUNCTURIST                                     1             1  ...     1       1
# ...                                             ...           ...  ...   ...     ...
# X-RAY LABORATORY AIDE                            26            26  ...    26      26
# X-Ray Laboratory Aide                           100           100  ...   100     100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    1             1  ...     1       1
# ...

# %%
df.groupby('JobTitle').count().sort_values('EmployeeName')
# Out:
#                                          Id  EmployeeName  ...  Year  Agency
# JobTitle                                                   ...
# ZOO CURATOR                               1             1  ...     1       1
# DIRECTOR, HUMAN RESOURCES                 1             1  ...     1       1
# DIRECTOR, FISCAL SERVICES                 1             1  ...     1       1
# DIRECTOR, EMPLOYEE RELATIONS DIVISION     1             1  ...     1       1
# Sr Cnselor, Juv Hall (SFERS)              1             1  ...     1       1
# ...                                     ...           ...  ...   ...     ...
# Police Officer 3                       2411          2411  ...  2411    2411
# Public Svc Aide-Public Works           2514          2514  ...  2514    2514
# Registered Nurse                       3725          3725  ...  3725    3725
# Special Nurse                          4382          4382  ...  4382    4382
# ...

# %%
df.groupby('JobTitle').count().sort_values('EmployeeName', ascending=False)
# Out:
#                                      Id  EmployeeName  ...  Year  Agency
# JobTitle                                               ...
# Transit Operator                   6975          6975  ...  6975    6975
# Special Nurse                      4382          4382  ...  4382    4382
# Registered Nurse                   3725          3725  ...  3725    3725
# Public Svc Aide-Public Works       2514          2514  ...  2514    2514
# Police Officer 3                   2411          2411  ...  2411    2411
# ...                                 ...           ...  ...   ...     ...
# METALSMITH                            1             1  ...     1       1
# METAL FABRICATOR                      1             1  ...     1       1
# MENTAL HEALTH HEARING OFFICER         1             1  ...     1       1
# MEDIA/SECURITY SYSTEMS SUPERVISOR     1             1  ...     1       1
# ZOO CURATOR                           1             1  ...     1       1
#
# [2154 rows x 10 columns]

# %%
df.groupby('JobTitle').count().sort_values('EmployeeName', ascending=False).head()
# Out:
#                                 Id  EmployeeName  ...  Year  Agency
# JobTitle                                          ...
# Transit Operator              6975          6975  ...  6975    6975
# Special Nurse                 4382          4382  ...  4382    4382
# Registered Nurse              3725          3725  ...  3725    3725
# Public Svc Aide-Public Works  2514          2514  ...  2514    2514
# Police Officer 3              2411          2411  ...  2411    2411
#
# [5 rows x 10 columns]

# %%
df.groupby('JobTitle').count().sort_values('EmployeeName', ascending=False).head()[['EmployeeName']]
# Out:
#                               EmployeeName
# JobTitle
# Transit Operator                      6975
# Special Nurse                         4382
# Registered Nurse                      3725
# Public Svc Aide-Public Works          2514
# Police Officer 3                      2411

# %% [markdown]
# #### JobTitle menjadi kolom

# %%
df.groupby('JobTitle', as_index=False)

# %%
df.groupby('JobTitle', as_index=False).count()
# Out:
#                                             JobTitle   Id  ...  Year  Agency
# 0                                      ACCOUNT CLERK   83  ...    83      83
# 1                                         ACCOUNTANT    5  ...     5       5
# 2                                  ACCOUNTANT INTERN   48  ...    48      48
# 3                        ACPO,JuvP, Juv Prob (SFERS)    1  ...     1       1
# 4                                      ACUPUNCTURIST    1  ...     1       1
# ...                                              ...  ...  ...   ...     ...
# 2149                           X-RAY LABORATORY AIDE   26  ...    26      26
# 2150                           X-Ray Laboratory Aide  100  ...   100     100
# 2151  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    1  ...     1       1
# 2152                              Youth Comm Advisor    4  ...     4       4
# 2153                                     ZOO CURATOR    1  ...     1       1
#
# [2154 rows x 11 columns]

# %%
df.groupby('JobTitle', as_index=False).count().sort_values('EmployeeName')
# Out:
#                                    JobTitle    Id  ...  Year  Agency
# 2153                            ZOO CURATOR     1  ...     1       1
# 599               DIRECTOR, HUMAN RESOURCES     1  ...     1       1
# 598               DIRECTOR, FISCAL SERVICES     1  ...     1       1
# 597   DIRECTOR, EMPLOYEE RELATIONS DIVISION     1  ...     1       1
# 1909           Sr Cnselor, Juv Hall (SFERS)     1  ...     1       1
# ...                                     ...   ...  ...   ...     ...
# 1478                       Police Officer 3  2411  ...  2411    2411
# 1539           Public Svc Aide-Public Works  2514  ...  2514    2514
# 1572                       Registered Nurse  3725  ...  3725    3725
# 1897                          Special Nurse  4382  ...  4382    4382
# 2051                       Transit Operator  6975  ...  6975    6975
#
# [2154 rows x 11 columns]

# %%
df.groupby('JobTitle', as_index=False).count().sort_values('EmployeeName',ascending=False)
# Out:
#                                JobTitle    Id  ...  Year  Agency
# 2051                   Transit Operator  6975  ...  6975    6975
# 1897                      Special Nurse  4382  ...  4382    4382
# 1572                   Registered Nurse  3725  ...  3725    3725
# 1539       Public Svc Aide-Public Works  2514  ...  2514    2514
# 1478                   Police Officer 3  2411  ...  2411    2411
# ...                                 ...   ...  ...   ...     ...
# 1161                         METALSMITH     1  ...     1       1
# 1160                   METAL FABRICATOR     1  ...     1       1
# 1157      MENTAL HEALTH HEARING OFFICER     1  ...     1       1
# 1143  MEDIA/SECURITY SYSTEMS SUPERVISOR     1  ...     1       1
# 2153                        ZOO CURATOR     1  ...     1       1
#
# [2154 rows x 11 columns]

# %%
df.groupby('JobTitle', as_index=False).count().sort_values('EmployeeName', ascending=False).head()
# Out:
#                           JobTitle    Id  ...  Year  Agency
# 2051              Transit Operator  6975  ...  6975    6975
# 1897                 Special Nurse  4382  ...  4382    4382
# 1572              Registered Nurse  3725  ...  3725    3725
# 1539  Public Svc Aide-Public Works  2514  ...  2514    2514
# 1478              Police Officer 3  2411  ...  2411    2411
#
# [5 rows x 11 columns]

# %%
df.groupby('JobTitle', as_index=False).count().sort_values('EmployeeName', ascending=False).head()[['JobTitle','EmployeeName']]
# Out:
#                           JobTitle  EmployeeName
# 2051              Transit Operator          6975
# 1897                 Special Nurse          4382
# 1572              Registered Nurse          3725
# 1539  Public Svc Aide-Public Works          2514
# 1478              Police Officer 3          2411

# %% [markdown]
# ## **No.7**

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.Series.str.extract.html

# %%
df['EmployeeName'].str.extract(r'(\w+) (\w+)', expand=True)
# Out:
#                   0         1
# 0         NATHANIEL      FORD
# 1              GARY   JIMENEZ
# 2            ALBERT   PARDINI
# 3       CHRISTOPHER     CHONG
# 4           PATRICK   GARDNER
# ...             ...       ...
# 148645      Carolyn         A
# 148647        Joann  Anderson
# 148648         Leon    Walker
# 148649          Roy         I
# 148653          Joe     Lopez
#
# [148045 rows x 2 columns]

# %% [markdown]
# ### Buatlah kolom baru yang isinya merupakan Last Name dari tiap orang

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html
# 1. https://www.tutorialspoint.com/python3/string_split.htm

# %%
df['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148645     Carolyn A Wilson
# 148647       Joann Anderson
# 148648          Leon Walker
# 148649        Roy I Tillery
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148045, dtype: object

# %%
df['EmployeeName'].apply(lambda x: x.split()[-1])
# Out:
# 0             FORD
# 1          JIMENEZ
# 2          PARDINI
# 3            CHONG
# 4          GARDNER
#             ...
# 148645      Wilson
# 148647    Anderson
# 148648      Walker
# 148649     Tillery
# 148653       Lopez
# Name: EmployeeName, Length: 148045, dtype: object

# %%
df['EmployeeName'].apply(lambda x: x.split()[0])
# Out:
# 0           NATHANIEL
# 1                GARY
# 2              ALBERT
# 3         CHRISTOPHER
# 4             PATRICK
#              ...
# 148645        Carolyn
# 148647          Joann
# 148648           Leon
# 148649            Roy
# 148653            Joe
# Name: EmployeeName, Length: 148045, dtype: object

# %%
df['LastName'] = df['EmployeeName'].apply(lambda x: x.split()[-1])

df[:3]
# Out:
#    Id    EmployeeName  ...         Agency  LastName
# 0   1  NATHANIEL FORD  ...  San Francisco      FORD
# 1   2    GARY JIMENEZ  ...  San Francisco   JIMENEZ
# 2   3  ALBERT PARDINI  ...  San Francisco   PARDINI
#
# [3 rows x 12 columns]

# %%
df.assign(LastName = df.EmployeeName.str.split().str[-1])

# %% [markdown]
# ## **No.8**

# %% [markdown]
# ### Ada berapa JobTitle yang hanya punya 1 karyawan di tahun 2013

# %%
jt13 = df[df['Year']==2013].groupby('JobTitle')['EmployeeName'].count()
# jt13[jt13 == 1].index.tolist()
display(jt13[jt13 == 1].sum())
display(len(jt13[jt13 == 1]))
# Out:
# 202
# 202

# %%
df['Year']
# Out:
# 0         2011
# 1         2011
# 2         2011
# 3         2011
# 4         2011
#           ...
# 148645    2014
# 148647    2014
# 148648    2014
# 148649    2014
# 148653    2014
# Name: Year, Length: 148045, dtype: int64

# %%
df['Year']==2013
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: Year, Length: 148045, dtype: bool

# %%
df[df['Year']==2013]
# Out:
#             Id          EmployeeName                        JobTitle  \
# 72925    72926        Gregory P Suhr                 Chief of Police
# 72926    72927  Joanne M Hayes-White          Chief, Fire Department
# 72927    72928           Samson  Lai  Battalion Chief, Fire Suppress
# 72928    72929       Ellen G Moffatt               Asst Med Examiner
# 72929    72930         Robert L Shaw    Dep Dir for Investments, Ret
# ...        ...                   ...                             ...
# 110514  110515    Michael A Denunzio      BdComm Mbr, Grp2,M=$25/Mtg
# 110515  110516      Rebecca J Prowda      BdComm Mbr, Grp2,M=$25/Mtg
# 110518  110519       Baltazar J Mata          Public Service Trainee
# 110519  110520     Leol Aaron Amador          Public Service Trainee
# 110520  110521     Carlos J Hernadez          Public Service Trainee
#
#           BasePay  OvertimePay  OtherPay  Benefits   TotalPay  \
# 72925   319275.01         0.00  20007.06  86533.21  339282.07
# ...

# %%
df[df['Year']==2013].groupby('JobTitle')

# %%
df[df['Year']==2013].groupby('JobTitle').count()
# Out:
#                                 Id  EmployeeName  BasePay  OvertimePay  \
# JobTitle
# ASR Senior Office Specialist    21            21       21           21
# ASR-Office Assistant            15            15       15           15
# Account Clerk                   87            87       87           87
# Accountant I                     3             3        3            3
# Accountant II                   77            77       77           77
# ...                             ..           ...      ...          ...
# Wire Rope Cable Maint Sprv       1             1        1            1
# Worker's Comp Supervisor 1       3             3        3            3
# Worker's Compensation Adjuster  25            25       25           25
# X-Ray Laboratory Aide           34            34       34           34
# Youth Comm Advisor               2             2        2            2
#
#                                 OtherPay  Benefits  TotalPay  \
# JobTitle
# ...

# %%
df[df['Year']==2013].groupby('JobTitle',as_index=False).count()
# Out:
#                             JobTitle  Id  EmployeeName  BasePay  OvertimePay  \
# 0       ASR Senior Office Specialist  21            21       21           21
# 1               ASR-Office Assistant  15            15       15           15
# 2                      Account Clerk  87            87       87           87
# 3                       Accountant I   3             3        3            3
# 4                      Accountant II  77            77       77           77
# ...                              ...  ..           ...      ...          ...
# 1036      Wire Rope Cable Maint Sprv   1             1        1            1
# 1037      Worker's Comp Supervisor 1   3             3        3            3
# 1038  Worker's Compensation Adjuster  25            25       25           25
# 1039           X-Ray Laboratory Aide  34            34       34           34
# 1040              Youth Comm Advisor   2             2        2            2
#
# ...

# %%
job_count = df[df['Year']==2013].groupby('JobTitle',as_index=False).count()
job_count
# Out:
#                             JobTitle  Id  EmployeeName  BasePay  OvertimePay  \
# 0       ASR Senior Office Specialist  21            21       21           21
# 1               ASR-Office Assistant  15            15       15           15
# 2                      Account Clerk  87            87       87           87
# 3                       Accountant I   3             3        3            3
# 4                      Accountant II  77            77       77           77
# ...                              ...  ..           ...      ...          ...
# 1036      Wire Rope Cable Maint Sprv   1             1        1            1
# 1037      Worker's Comp Supervisor 1   3             3        3            3
# 1038  Worker's Compensation Adjuster  25            25       25           25
# 1039           X-Ray Laboratory Aide  34            34       34           34
# 1040              Youth Comm Advisor   2             2        2            2
#
# ...

# %%
job_count['Id']
# Out:
# 0       21
# 1       15
# 2       87
# 3        3
# 4       77
#         ..
# 1036     1
# 1037     3
# 1038    25
# 1039    34
# 1040     2
# Name: Id, Length: 1041, dtype: int64

# %%
job_count['Id']==1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1036     True
# 1037    False
# 1038    False
# 1039    False
# 1040    False
# Name: Id, Length: 1041, dtype: bool

# %%
job_count[job_count['Id']==1].count()
# Out:
# JobTitle            202
# Id                  202
# EmployeeName        202
# BasePay             202
# OvertimePay         202
# OtherPay            202
# Benefits            202
# TotalPay            202
# TotalPayBenefits    202
# Year                202
# Agency              202
# dtype: int64

# %%
job_count[job_count['Id']==1].count()['Id']
# Out:
# 202

# %% [markdown]
# #### cara lain

# %%
df[df['Year']==2013]
# Out:
#             Id          EmployeeName  ...         Agency     LastName
# 72925    72926        Gregory P Suhr  ...  San Francisco         Suhr
# 72926    72927  Joanne M Hayes-White  ...  San Francisco  Hayes-White
# 72927    72928           Samson  Lai  ...  San Francisco          Lai
# 72928    72929       Ellen G Moffatt  ...  San Francisco      Moffatt
# 72929    72930         Robert L Shaw  ...  San Francisco         Shaw
# ...        ...                   ...  ...            ...          ...
# 110514  110515    Michael A Denunzio  ...  San Francisco     Denunzio
# 110515  110516      Rebecca J Prowda  ...  San Francisco       Prowda
# 110518  110519       Baltazar J Mata  ...  San Francisco         Mata
# 110519  110520     Leol Aaron Amador  ...  San Francisco       Amador
# 110520  110521     Carlos J Hernadez  ...  San Francisco     Hernadez
#
# [37001 rows x 12 columns]

# %%
df[df['Year']==2013]['JobTitle']
# Out:
# 72925                    Chief of Police
# 72926             Chief, Fire Department
# 72927     Battalion Chief, Fire Suppress
# 72928                  Asst Med Examiner
# 72929       Dep Dir for Investments, Ret
#                        ...
# 110514        BdComm Mbr, Grp2,M=$25/Mtg
# 110515        BdComm Mbr, Grp2,M=$25/Mtg
# 110518            Public Service Trainee
# 110519            Public Service Trainee
# 110520            Public Service Trainee
# Name: JobTitle, Length: 37001, dtype: object

# %%
df[df['Year']==2013]['JobTitle'].value_counts()
# Out:
# Transit Operator                 2234
# Special Nurse                    1438
# Registered Nurse                 1220
# Public Svc Aide-Public Works      855
# Custodian                         780
#                                  ...
# Emergency Services Assistant        1
# Trnst Power Line Wrk Sprv 2         1
# Water Meter Shop Supervisor 1       1
# District Attorney                   1
# Director, Info Tech Group           1
# Name: JobTitle, Length: 1041, dtype: int64

# %%
df[df['Year']==2013]['JobTitle'].value_counts()==1
# Out:
# Transit Operator                 False
# Special Nurse                    False
# Registered Nurse                 False
# Public Svc Aide-Public Works     False
# Custodian                        False
#                                  ...
# Emergency Services Assistant      True
# Trnst Power Line Wrk Sprv 2       True
# Water Meter Shop Supervisor 1     True
# District Attorney                 True
# Director, Info Tech Group         True
# Name: JobTitle, Length: 1041, dtype: bool

# %%
(df[df['Year']==2013]['JobTitle'].value_counts()==1).sum()
# Out:
# 202

# %%
a = df[df['Year']==2013]['JobTitle'].value_counts()==1
a
# Out:
# Transit Operator                 False
# Special Nurse                    False
# Registered Nurse                 False
# Public Svc Aide-Public Works     False
# Custodian                        False
#                                  ...
# Emergency Services Assistant      True
# Trnst Power Line Wrk Sprv 2       True
# Water Meter Shop Supervisor 1     True
# District Attorney                 True
# Director, Info Tech Group         True
# Name: JobTitle, Length: 1041, dtype: bool

# %%
a.sum()
# Out:
# 202

# %% [markdown]
# ## **No.9**

# %%
# d = df[df['Year']==2013]['JobTitle']
# re.search('Chief', str(d))
# Out:
# <regex.Match object; span=(25, 30), match='Chief'>

# %% [markdown]
# ### Ada berapa orang yang punya kata Chief pada JobTitle-nya?

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.Series.str.lower.html
# 1. https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148645                         Human Services Technician
# 148647                       Communications Dispatcher 2
# 148648                                         Custodian
# 148649                                         Custodian
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148045, dtype: object

# %%
df['JobTitle'].str.lower()
# Out:
# 0         general manager-metropolitan transit authority
# 1                        captain iii (police department)
# 2                        captain iii (police department)
# 3                   wire rope cable maintenance mechanic
# 4           deputy chief of department,(fire department)
#                                ...
# 148645                         human services technician
# 148647                       communications dispatcher 2
# 148648                                         custodian
# 148649                                         custodian
# 148653                        counselor, log cabin ranch
# Name: JobTitle, Length: 148045, dtype: object

# %%
df['JobTitle'].str.lower().str.contains('chief')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 148645    False
# 148647    False
# 148648    False
# 148649    False
# 148653    False
# Name: JobTitle, Length: 148045, dtype: bool

# %%
df['JobTitle'].str.lower().str.contains('chief').sum()
# Out:
# 624

# %%
x['JobTitle'].str.contains('Chief').value_counts()[True]

# %% [markdown]
# ## **No.10**

# %%
df_new = df[['JobTitle','Year','BasePay']].groupby(['JobTitle','Year']).mean()
df_new#.sort_index()
# Out:
#                                                           BasePay
# JobTitle                                       Year
# ACCOUNT CLERK                                  2011  43300.806506
# ACCOUNTANT                                     2011  46643.172000
# ACCOUNTANT INTERN                              2011  28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                    2014  62290.780000
# ACUPUNCTURIST                                  2011  66374.400000
# ...                                                           ...
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS 2011  52609.910000
# Youth Comm Advisor                             2012  57544.730000
#                                                2013  33174.840000
#                                                2014  32417.420000
# ZOO CURATOR                                    2011  43148.000000
#
# [4126 rows x 1 columns]

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# %%
df.pivot_table(
    index='JobTitle',
    columns='Year',
    values='BasePay',
    aggfunc=np.mean
)
# Out:
# Year                                                    2011  ...          2014
# JobTitle                                                      ...
# ACCOUNT CLERK                                   43300.806506  ...           NaN
# ACCOUNTANT                                      46643.172000  ...           NaN
# ACCOUNTANT INTERN                               28732.663958  ...           NaN
# ACPO,JuvP, Juv Prob (SFERS)                              NaN  ...  62290.780000
# ACUPUNCTURIST                                   66374.400000  ...           NaN
# ...                                                      ...  ...           ...
# X-RAY LABORATORY AIDE                           47664.773077  ...           NaN
# X-Ray Laboratory Aide                                    NaN  ...  45490.340286
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.910000  ...           NaN
# Youth Comm Advisor                                       NaN  ...  32417.420000
# ...

# %% [markdown]
# # **Dataset: audi.csv, hyundai.csv, toyota.csv**
#
# Dataset: https://www.kaggle.com/adityadesai13/used-car-dataset-ford-and-mercedes?select=toyota.csv

# %%
df_audi = pd.read_csv('/content/drive/MyDrive/JCDS Practice Session VL-04, 06/Modul 2/Week 3/Thursday, June 02, 2022/audi.csv')
df_audi.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
df_hyundai = pd.read_csv('/content/drive/MyDrive/JCDS Practice Session VL-04, 06/Modul 2/Week 3/Thursday, June 02, 2022/hyundai.csv')
df_hyundai.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax(£)   mpg  \
# 0      I20  2017   7999       Manual    17307   Petrol     145  58.9
# 1   Tucson  2016  14499    Automatic    25233   Diesel     235  43.5
# 2   Tucson  2016  11399       Manual    37877   Diesel      30  61.7
# 3      I10  2016   6499       Manual    23789   Petrol      20  60.1
# 4     IX35  2015  10199       Manual    33177   Diesel     160  51.4
#
#    engineSize
# 0         1.2
# 1         2.0
# 2         1.7
# 3         1.0
# 4         2.0

# %%
df_toyota = pd.read_csv('/content/drive/MyDrive/JCDS Practice Session VL-04, 06/Modul 2/Week 3/Thursday, June 02, 2022/toyota.csv')
df_toyota.head()
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0

# %% [markdown]
# ## **No.1**

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html

# %%
# Jika Anda perhatikan, nama kolom 'tax(£)' di dataset hyundai berbeda dengan di dataset lainnya.
# Ubah nama kolom tersebut menjadi 'tax' agar sama dengan di dataset yang lain.

df_hyundai.rename(columns={'tax(£)':'tax'}, inplace=True)
df_hyundai.head(3)
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0      I20  2017   7999       Manual    17307   Petrol  145  58.9         1.2
# 1   Tucson  2016  14499    Automatic    25233   Diesel  235  43.5         2.0
# 2   Tucson  2016  11399       Manual    37877   Diesel   30  61.7         1.7

# %% [markdown]
# ## **No.2**

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.insert.html

# %%
df_audi.insert(0, 'brand', value='Audi')
df_hyundai.insert(0, 'brand', value='Hyundai')
df_toyota.insert(0, 'brand', value='Toyota')

# %%
df_toyota[:3]
# Out:
#     brand  model  year  price transmission  mileage fuelType  tax   mpg  \
# 0  Toyota   GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1  Toyota   GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2  Toyota   GT86  2015  13998       Manual    27469   Petrol  265  36.2
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         2.0

# %% [markdown]
# ## **No.3**

# %% [markdown]
# 1. https://pandas.pydata.org/docs/reference/api/pandas.concat.html

# %%
df_car = pd.concat([df_audi,df_hyundai,df_toyota], axis=0, ignore_index=True)
df_car
# Out:
#         brand           model  year  price transmission  mileage fuelType  \
# 0        Audi              A1  2017  12500       Manual    15735   Petrol
# 1        Audi              A6  2016  16500    Automatic    36203   Diesel
# 2        Audi              A1  2016  11000       Manual    29946   Petrol
# 3        Audi              A4  2017  16800    Automatic    25952   Diesel
# 4        Audi              A3  2019  17300       Manual     1998   Petrol
# ...       ...             ...   ...    ...          ...      ...      ...
# 22261  Toyota              IQ  2011   5500    Automatic    30000   Petrol
# 22262  Toyota   Urban Cruiser  2011   4985       Manual    36154   Petrol
# 22263  Toyota   Urban Cruiser  2012   4995       Manual    46000   Diesel
# 22264  Toyota   Urban Cruiser  2011   3995       Manual    60700   Petrol
# 22265  Toyota   Urban Cruiser  2011   4495       Manual    45128   Petrol
#
#        tax   mpg  engineSize
# 0      150  55.4         1.4
# ...

# %% [markdown]
# ## **No.4**

# %% [markdown]
# 1. https://pandas.pydata.org/pandas-docs/version/1.2.4/reference/api/pandas.Series.str.strip.html

# %%
df_car['model']
# Out:
# 0                    A1
# 1                    A6
# 2                    A1
# 3                    A4
# 4                    A3
#               ...
# 22261                IQ
# 22262     Urban Cruiser
# 22263     Urban Cruiser
# 22264     Urban Cruiser
# 22265     Urban Cruiser
# Name: model, Length: 22266, dtype: object

# %%
df_car['model'].apply(lambda x: len(x))[:5]
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: model, dtype: int64

# %%
df_car['model'] = df_car['model'].str.strip()

# %%
df_car['model'].apply(lambda x: len(x))[:5]
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: model, dtype: int64

# %% [markdown]
# ## **No.5**

# %%
df_car.groupby(by=['brand','transmission'], as_index=False).mean().sort_values(by='tax', ascending=False)
# Out:
#       brand transmission         year         price       mileage         tax  \
# 3   Hyundai    Automatic  2017.309417  16369.224215  19888.995516  151.449925
# 0      Audi    Automatic  2017.510340  28204.750000  21359.902880  149.411004
# 6   Hyundai    Semi-Auto  2017.844291  19119.217993  16495.787197  148.711073
# 2      Audi    Semi-Auto  2017.651629  27161.781676  19953.927318  143.517126
# 10   Toyota    Semi-Auto  2017.015748  14797.137795  16967.830709  124.015748
# 4   Hyundai       Manual  2016.952368  11059.049571  22577.735807  111.147881
# 8    Toyota       Manual  2016.759801   9551.496864  22472.350497  104.218505
# 1      Audi       Manual  2016.393912  16101.033417  30981.888075   97.119478
# 7    Toyota    Automatic  2016.706436  16582.828754  23977.222431   78.219797
# 5   Hyundai        Other  2017.000000  14745.000000  26847.000000   72.500000
# 9    Toyota        Other  2015.000000  12795.000000  16733.000000    0.000000
#
#           mpg  engineSize
# ...

# %%
df_car.pivot_table(
    index='brand',
    columns='transmission',
    values='tax',
    aggfunc=np.mean,
    fill_value=0
).sort_values(by=['Automatic','Manual','Other','Semi-Auto'],ascending=False)

# %% [markdown]
# ## **No.6**

# %%
# buat dataframe untuk mobil Camry saja
df_camry = df_car[df_car['model']=='Camry']
df_camry
# Out:
#         brand  model  year  price transmission  mileage fuelType  tax   mpg  \
# 22240  Toyota  Camry  2019  29990    Automatic     4600   Hybrid  135  52.3
# 22241  Toyota  Camry  2019  25990    Automatic     6000   Hybrid  135  52.3
# 22242  Toyota  Camry  2019  24990    Automatic     5145   Hybrid  135  52.3
# 22243  Toyota  Camry  2020  26490    Automatic    10000   Hybrid  135  52.3
# 22244  Toyota  Camry  2019  27545    Automatic     5059   Hybrid  135  52.3
# 22245  Toyota  Camry  2019  28495    Automatic     4998   Hybrid  140  52.3
# 22246  Toyota  Camry  2019  26491    Automatic     4416   Hybrid  135  52.3
# 22247  Toyota  Camry  2019  27550    Automatic     4189   Hybrid  135  52.3
# 22248  Toyota  Camry  2019  25490    Automatic     6340   Hybrid  135  52.3
# 22249  Toyota  Camry  2019  26990    Automatic     3000   Hybrid  135  52.3
# 22250  Toyota  Camry  2019  25990    Automatic    10732   Hybrid  135  52.3
#
#        engineSize
# 22240         2.5
# ...

# %%
# buat kolom baru untuk menandakan apakah mobil tsb di bawah rata-rata mileage
df_camry['mileage_under'] = df_camry[['mileage']] < df_camry[['mileage']].mean()
df_camry
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         brand  model  year  price transmission  mileage fuelType  tax   mpg  \
# 22240  Toyota  Camry  2019  29990    Automatic     4600   Hybrid  135  52.3
# 22241  Toyota  Camry  2019  25990    Automatic     6000   Hybrid  135  52.3
# 22242  Toyota  Camry  2019  24990    Automatic     5145   Hybrid  135  52.3
# 22243  Toyota  Camry  2020  26490    Automatic    10000   Hybrid  135  52.3
# 22244  Toyota  Camry  2019  27545    Automatic     5059   Hybrid  135  52.3
# 22245  Toyota  Camry  2019  28495    Automatic     4998   Hybrid  140  52.3
# 22246  Toyota  Camry  2019  26491    Automatic     4416   Hybrid  135  52.3
# ...

# %%
# buat kolom baru untuk menandakan apakah mobil tsb di bawah rata-rata harga
df_camry['price_under'] = df_camry[['price']] < df_camry[['price']].mean()
df_camry
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         brand  model  year  price transmission  mileage fuelType  tax   mpg  \
# 22240  Toyota  Camry  2019  29990    Automatic     4600   Hybrid  135  52.3
# 22241  Toyota  Camry  2019  25990    Automatic     6000   Hybrid  135  52.3
# 22242  Toyota  Camry  2019  24990    Automatic     5145   Hybrid  135  52.3
# 22243  Toyota  Camry  2020  26490    Automatic    10000   Hybrid  135  52.3
# 22244  Toyota  Camry  2019  27545    Automatic     5059   Hybrid  135  52.3
# 22245  Toyota  Camry  2019  28495    Automatic     4998   Hybrid  140  52.3
# 22246  Toyota  Camry  2019  26491    Automatic     4416   Hybrid  135  52.3
# ...

# %%
# Kondisi yang keduanya True
df_camry[(df_camry['mileage_under']==True) & (df_camry['price_under']==True)]
# Out:
#         brand  model  year  price transmission  mileage fuelType  tax   mpg  \
# 22242  Toyota  Camry  2019  24990    Automatic     5145   Hybrid  135  52.3
# 22246  Toyota  Camry  2019  26491    Automatic     4416   Hybrid  135  52.3
#
#        engineSize  mileage_under  price_under
# 22242         2.5           True         True
# 22246         2.5           True         True

# %% [markdown]
# ## **No.7**

# %%
# save to csv
df_car.to_csv('all_cars.csv')

# %%
from google.colab import files
files.download("all_cars.csv")

# %%
engine_0 = df_car[df_car['engineSize']==0].reset_index().iloc[:, 1:]
engine_0.head()
# Out:
#   brand model  year  price  ... fuelType  tax    mpg  engineSize
# 0  Audi    Q5  2019  44790  ...   Petrol  135  117.7         0.0
# 1  Audi    Q3  2019  32788  ...   Diesel  145   47.1         0.0
# 2  Audi    Q3  2020  29944  ...   Petrol  145   40.9         0.0
# 3  Audi    Q3  2020  33333  ...   Diesel  145   47.1         0.0
# 4  Audi    Q3  2020  29944  ...   Petrol  145   32.5         0.0
#
# [5 rows x 10 columns]

# %%
for i in range(len(engine_0)):
    if engine_0.iloc[0]['model']=='Q5':
        engine_0.iloc[0]['engineSize'] = engine_0.iloc[0]['engineSize'] + 1.7
    else:
        engine_0.iloc[0]['engineSize'] = engine_0.iloc[0]['engineSize'] + 2.4

engine_0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       brand  model  year  price  ... fuelType  tax    mpg  engineSize
# 0      Audi     Q5  2019  44790  ...   Petrol  135  117.7         0.0
# 1      Audi     Q3  2019  32788  ...   Diesel  145   47.1         0.0
# 2      Audi     Q3  2020  29944  ...   Petrol  145   40.9         0.0
# 3      Audi     Q3  2020  33333  ...   Diesel  145   47.1         0.0
# 4      Audi     Q3  2020  29944  ...   Petrol  145   32.5         0.0
# ..      ...    ...   ...    ...  ...      ...  ...    ...         ...
# 105  Toyota  Yaris  2016  11000  ...   Hybrid    0   86.0         0.0
# ...

# %% [markdown]
# # **Dataset: province.csv**

# %%
df = pd.read_csv('/content/drive/MyDrive/JCDSVL-04, 06, 07, JCDSOL-09, JCDSAHLS-01 Practice Session/Modul 2/Week 3/Monday, February 20, 2023/province.csv')
df.head()
# Out:
#                  Name Capital of Province      Island     Area
# 0    Kalimantan Barat           Pontianak  Kalimantan   118.30
# 1    Kalimantan Timur           Samarinda  Kalumantan   718.00
# 2  Kalimantan Selatan         Banjarmasin  Kalimantan    98.46
# 3   Kalimantan Tengah        Palangkaraya  Kalimantan  2853.00
# 4    Kalimantan Utara       Tanjung Selor  Kalumantan   120.50

# %% [markdown]
# ## **No.1**

# %%
df['Island'].unique()
# Out:
# array(['Kalimantan', 'Kalumantan', 'Jawa'], dtype=object)

# %%
def fixTypo(x):
  if x == 'Kalumantan':
    return 'Kalimantan'
  else:
    return x
df['Island'] = df['Island'].apply(fixTypo)

# %%
df['Island'].unique()
# Out:
# array(['Kalimantan', 'Jawa'], dtype=object)

# %% [markdown]
# ## **No.2**

# %%
df['Name'].unique()
# Out:
# array(['Kalimantan Barat', 'Kalimantan Timur', 'Kalimantan Selatan',
#        'Kalimantan Tengah', 'Kalimantan Utara', 'Banteng', 'DKI Jakarta',
#        'Jawa Barat', 'Jateng', 'DI Yogyakarta', 'Jatim'], dtype=object)

# %%
def fixProvince(x):
  if x == 'Jateng':
    return 'Jawa Tengah'
  elif x == 'Jatim':
    return 'Jawa Timur'
  elif x == 'Banteng':
    return 'Banten'
  else:
    return x
df['Name'] = df['Name'].apply(fixProvince)

# %%
df['Name'].unique()
# Out:
# array(['Kalimantan Barat', 'Kalimantan Timur', 'Kalimantan Selatan',
#        'Kalimantan Tengah', 'Kalimantan Utara', 'Banteng', 'DKI Jakarta',
#        'Jawa Barat', 'Jawa Tengah', 'DI Yogyakarta', 'Jawa Timur'],
#       dtype=object)

# %% [markdown]
# ## **No.3**

# %%
duplicate_data = df.duplicated(keep = False)
df[duplicate_data]
# Out:
#              Name Capital of Province Island  Area
# 9   DI Yogyakarta          Yogyakarta   Jawa  32.5
# 10  DI Yogyakarta          Yogyakarta   Jawa  32.5

# %%
duplicate_data = df.duplicated()
df[duplicate_data]
# Out:
#              Name Capital of Province Island  Area
# 10  DI Yogyakarta          Yogyakarta   Jawa  32.5

# %%
df = df[~duplicate_data]
df
# Out:
#                   Name Capital of Province      Island     Area
# 0     Kalimantan Barat           Pontianak  Kalimantan   118.30
# 1     Kalimantan Timur           Samarinda  Kalimantan   718.00
# 2   Kalimantan Selatan         Banjarmasin  Kalimantan    98.46
# 3    Kalimantan Tengah        Palangkaraya  Kalimantan  2853.00
# 4     Kalimantan Utara       Tanjung Selor  Kalimantan   120.50
# 5              Banteng              Serang        Jawa   266.70
# 6          DKI Jakarta             Jakarta        Jawa   661.50
# 7           Jawa Barat             Bandung        Jawa   167.30
# 8          Jawa Tengah            Semarang        Jawa   373.80
# 9        DI Yogyakarta          Yogyakarta        Jawa    32.50
# 11          Jawa Timur            Surabaya        Jawa   326.50

# %%
df[duplicate_data]
# Out:
# <ipython-input-15-183c37114d89>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[duplicate_data]
# Empty DataFrame
# Columns: [Name, Capital of Province, Island, Area]
# Index: []

# %% [markdown]
# ## **No.4**

# %%
df[['Island', 'Area']].groupby(['Island']).sum()
# Out:
#                Area
# Island
# Jawa        1828.30
# Kalimantan  3908.26

# %% [markdown]
# # **Dataset: date.csv**

# %%
df = pd.read_csv('/content/drive/MyDrive/JCDSVL-04, 06, 07, JCDSOL-09, JCDSAHLS-01 Practice Session/Modul 2/Week 3/Monday, February 20, 2023/date.csv')
df.head()
# Out:
#           timeStamp
# 0  12/10/2015 17:10
# 1  12/10/2015 17:29
# 2  12/10/2015 14:39
# 3  12/10/2015 16:47
# 4  12/10/2015 16:56

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283468 entries, 0 to 283467
# Data columns (total 1 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timeStamp  283468 non-null  object
# dtypes: object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# ## **No.1**

# %%
df['timeStamp'] = pd.to_datetime(df['timeStamp'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283468 entries, 0 to 283467
# Data columns (total 1 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timeStamp  283468 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.2 MB

# %% [markdown]
# ## **No.2**

# %%
df['year'] = df['timeStamp'].dt.year
# df['month'] = df['timeStamp'].dt.to_period('M')
df['hour'] = df['timeStamp'].apply(lambda time: time.hour)
df['month'] = df['timeStamp'].apply(lambda time: time.month)
df['day'] = df['timeStamp'].apply(lambda time: time.dayofweek)
#df['year'] = df['timeStamp'].apply(lambda time: time.year)
df.head()
# Out:
#             timeStamp  year  hour  month  day
# 0 2015-12-10 17:10:00  2015    17     12    3
# 1 2015-12-10 17:29:00  2015    17     12    3
# 2 2015-12-10 14:39:00  2015    14     12    3
# 3 2015-12-10 16:47:00  2015    16     12    3
# 4 2015-12-10 16:56:00  2015    16     12    3

# %%
# dfDate['hour'] = pd.DatetimeIndex(dfDate['timeStamp']).hour
# dfDate['month'] = pd.DatetimeIndex(dfDate['timeStamp']).month
# dfDate['day'] = pd.DatetimeIndex(dfDate['timeStamp']).day
# dfDate['year'] = pd.DatetimeIndex(dfDate['timeStamp']).year

# %% [markdown]
# ## **No.3**

# %%
dayMap = {0:'Monday',1:'Tuesday',2:'Wedensday',3:'Thursday',4:'Friday',5:'Saturday',6:'Sunday'}
df['day_of_week'] = df['day'].map(dayMap)
df.head()
# Out:
#             timeStamp  year  hour  month  day day_of_week
# 0 2015-12-10 17:10:00  2015    17     12    3    Thursday
# 1 2015-12-10 17:29:00  2015    17     12    3    Thursday
# 2 2015-12-10 14:39:00  2015    14     12    3    Thursday
# 3 2015-12-10 16:47:00  2015    16     12    3    Thursday
# 4 2015-12-10 16:56:00  2015    16     12    3    Thursday

# %%
# df['day_of_week'] = df['timeStamp'].dt.strftime('%A')

# %% [markdown]
# ## **No.4**

# %%
monthMap = {1:'January',2:'February',3:'March',4:'April', 5:'Mei',6:'June',7:'July', 8:'August', 9:'September', 10:'October', 11:'November', 12:'December'}
df['month_names'] = df['month'].map(monthMap)
df.head()
# Out:
#             timeStamp  year  hour  month  day day_of_week month_names
# 0 2015-12-10 17:10:00  2015    17     12    3    Thursday    December
# 1 2015-12-10 17:29:00  2015    17     12    3    Thursday    December
# 2 2015-12-10 14:39:00  2015    14     12    3    Thursday    December
# 3 2015-12-10 16:47:00  2015    16     12    3    Thursday    December
# 4 2015-12-10 16:56:00  2015    16     12    3    Thursday    December

# %%
# df['month_names'] = df['timeStamp'].dt.strftime('%B')

# %% [markdown]
# ## **No.5**

# %%
np.random.seed(32)
value = np.random.randint(1,100,df.shape[0]).reshape(df.shape[0],1)
df['value'] = value
df.head()
# Out:
#             timeStamp  year  hour  month  day day_of_week month_names  value
# 0 2015-12-10 17:10:00  2015    17     12    3    Thursday    December     88
# 1 2015-12-10 17:29:00  2015    17     12    3    Thursday    December     44
# 2 2015-12-10 14:39:00  2015    14     12    3    Thursday    December      6
# 3 2015-12-10 16:47:00  2015    16     12    3    Thursday    December     55
# 4 2015-12-10 16:56:00  2015    16     12    3    Thursday    December     63

# %%
# df['value'] = np.random.randint(1,100,len(df['timeStamp']))

# %% [markdown]
# ## **No.6**

# %%
df[['year', 'month', 'value']].groupby(by=['year', 'month']).sum()
# Out:
#              value
# year month
# 2015 12     393988
# 2016 1      651707
#      2      572737
#      3      557058
#      4      566897
#      5      575241
#      6      587846
#      7      602956
#      8      600629
#      9      583395
#      10     625784
#      11     604022
#      12     614121
# 2017 1      578629
#      2      512388
#      3      585538
#      4      554649
#      5      591510
#      6      617549
#      7      588161
#      8      593531
#      9      561673
#      10     615843
#      11     578907
#      12     287051

# %% [markdown]
# # **Bonus**

# %%
# Tampilkan rata-rata jarak tempuh (mileage) berdasarkan tahun,
# di mana rata-rata jarak tempuh (mileage) pada tahun tersebut di bawah median dari seluruh rata-rata jarak tempuh (mileage)
# Urutkan dari rata-rata jarak tempuh (mileage) yang paling kecil

avg_milePerYear = df_car.groupby('year').mean()[['mileage']]
avg_milePerYear[avg_milePerYear < avg_milePerYear.median()].sort_values('mileage')
# Out:
#            mileage
# year
# 2020   2807.960120
# 2019   5770.355719
# 2018  16682.354501
# 2017  24105.134451
# 2016  33237.949687
# 2000  34000.000000
# 2015  40665.752289
# 2014  45699.513211
# 2013  51601.291057
# 2012  61057.167785
# 2010  69029.866667
# 2011  70677.339623
# 1997           NaN
# 1998           NaN
# 1999           NaN
# 2001           NaN
# 2002           NaN
# 2003           NaN
# 2004           NaN
# 2005           NaN
# 2006           NaN
# 2007           NaN
# 2008           NaN
# 2009           NaN

# %%
# Mobil termahal
df_car.loc[df_car['price'].idxmax()]
# Out:
# brand                Audi
# model                  R8
# year                 2020
# price              145000
# transmission    Semi-Auto
# mileage              2000
# fuelType           Petrol
# tax                   145
# mpg                  21.1
# engineSize            5.2
# Name: 4783, dtype: object

# %%
# Mobil Toyota paling banyak yang keluaran tahun berapa
df_car[df_car['brand']=='Toyota']['year'].value_counts()
# Out:
# 2017    2019
# 2019    1286
# 2018    1015
# 2016     997
# 2015     525
# 2014     352
# 2013     204
# 2020     128
# 2012      42
# 2011      40
# 2009      29
# 2007      20
# 2008      19
# 2010      18
# 2005      12
# 2006      11
# 2004       7
# 2003       6
# 2002       4
# 1998       1
# 2001       1
# 1999       1
# 2000       1
# Name: year, dtype: int64

# %%
# Mobil Toyota keluaran tahun 2019 yang rata-rata untuk dipakai perjalanan jauh
df_2019 = df_car[df_car['year']==2019]

df_2019.groupby(['brand','model']).mean().loc['Toyota'].sort_values(by='mileage', ascending=False)[['mileage','mpg']]
# Out:
#                    mileage         mpg
# model
# Auris         13739.000000   66.666667
# Land Cruiser   9947.400000   30.100000
# RAV4           9489.173913   50.082609
# Hilux          9353.368421   29.178947
# C-HR           7376.074074   65.805556
# Corolla        6750.259912   65.876652
# Yaris          6012.118090   50.964322
# Prius          5622.459459  106.143243
# Camry          5447.900000   52.300000
# Aygo           4675.387863   56.939578
# PROACE VERSO   3999.692308   39.484615
# GT86           3777.842105   33.073684
# Supra          1999.083333   34.500000

# %%
# Jumlah mobil Toyota keluaran 2019 berdasarkan model
df_car[(df_car['brand']=='Toyota') & (df_car['year']==2019)]['model'].value_counts()
# Out:
# Yaris           398
# Aygo            379
# Corolla         227
# C-HR            108
# RAV4             46
# Prius            37
# GT86             19
# Hilux            19
# Land Cruiser     15
# PROACE VERSO     13
# Supra            12
# Camry            10
# Auris             3
# Name: model, dtype: int64
